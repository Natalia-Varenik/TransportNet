# %%
import pandas as pd
import numpy as np
import data_handler as dh
import model as md
import time
import os
import matplotlib.pyplot as plt
from matplotlib import rc
import pickle

# %%
import importlib
importlib.reload(dh)
importlib.reload(md)
# Out:
# <module 'model' from '/var/local/nvarenik/traffic_flows/TransportNet/Stable Dynamic & Beckman/model.py'>

# %%
import numba
numba.__version__
# Out:
# '0.54.1'

# %%
import sys
print(sys.executable)
print(sys.version)
print(sys.version_info)
from platform import python_version
print('python', python_version())
print('numpy', np.__version__)
print('pandas', pd.__version__)
import graph_tool
print('graph_tool', graph_tool.__version__)
# Out:
# /usr/bin/python3
# 3.9.5 (default, May 24 2021, 12:50:35)
# [GCC 11.1.0]
# sys.version_info(major=3, minor=9, micro=5, releaselevel='final', serial=0)
# python 3.9.5
# numpy 1.20.3
# pandas 1.2.5
# graph_tool 2.42 (commit 458bd492, Fri Jul 2 22:11:01 2021 +0200)

# %% [markdown]
# # Beckmann model
#
# parameter $\mu = 0.25$

# %%
beckmann_save = 'perturbation_results_free_flow_final/'
if not os.path.exists(beckmann_save):
    os.mkdir(beckmann_save)

# %%
net_name = 'Anaheim_net.tntp'
trips_name = 'Anaheim_trips.tntp'

handler = dh.DataHandler()
answer = handler.ReadAnswer('Anaheim_flow.tntp')
t_start = np.array(answer['times'])

graph_data = handler.GetGraphData(net_name, columns = ['init_node', 'term_node', 'capacity', 'free_flow_time'])
graph_correspondences, total_od_flow = handler.GetGraphCorrespondences(trips_name)
t_free_flow = graph_data['graph_table']['free_flow_time'].values

# %%
#perturbation
np.random.seed(17)
capacities = graph_data['graph_table']['capacity']
mask = np.random.binomial(n=1, p=0.05, size=capacities.shape)
weights = np.random.choice((-0.3, 0.3), size=capacities.shape)
perturbation = weights * (mask * capacities)

# adjust capacity by 
graph_data['graph_table']['capacity'] = capacities + perturbation

# %%
model = md.Model(graph_data, graph_correspondences, 
                    total_od_flow, mu = 0.25, rho = 0.15)

graph_data['graph_table'].head()
# Out:
#    init_node  init_node_thru  term_node  term_node_thru  capacity  \
# 0          1           False        117            True    9000.0
# 1          2           False         87            True    6300.0
# 2          3           False         74            True    9000.0
# 3          4           False        233            True    9000.0
# 4          5           False        165            True    9000.0
#
#    free_flow_time
# 0        1.090458
# 1        1.090458
# 2        1.090458
# 3        1.090458
# 4        1.090458

# %% [markdown]
# ## Frank-Wolfe method

# %%
#new prox oracle etc. t_weighted !!
assert(model.mu == 0.25)
max_iter = 10000

print('Frank-Wolfe without stopping criteria')
solver_kwargs = {'max_iter' : max_iter, 'stop_crit': 'max_iter',
                 'verbose' : True, 'verbose_step': 2000, 'save_history' : True}
tic = time.time()
result = model.find_equilibrium(solver_name = 'fwm', solver_kwargs = solver_kwargs, t_start = t_free_flow)#t_start)
toc = time.time()
print('Elapsed time: {:.0f} sec'.format(toc - tic))
print('Time ratio =', np.max(result['times'] / graph_data['graph_table']['free_flow_time']))
print('Flow excess =', np.max(result['flows'] / graph_data['graph_table']['capacity']) - 1, end = '\n\n')

with open(beckmann_save + 'anaheim_result_fwm_t_weighted_max_iter_10000_beckmann.pickle', 'wb') as f:
    pickle.dump(result, f)
# Out:
# Frank-Wolfe without stopping criteria
# Oracles created...
# Frank-Wolfe method...
# Given point is used as t_start...
# Primal_init = 1.29734e+06
# Dual_init = -1.24813e+06
# Duality_gap_init = 49206.9
#
# Iterations number: 2000
# Primal_func_value = 1.28753e+06
# Dual_func_value = -1.28753e+06
# Duality_gap = 0.422041
# Duality_gap / Duality_gap_init = 8.57688e-06
#
# Iterations number: 4000
# Primal_func_value = 1.28753e+06
# Dual_func_value = -1.28753e+06
# Duality_gap = 0.206956
# Duality_gap / Duality_gap_init = 4.20584e-06
#
# Iterations number: 6000
# Primal_func_value = 1.28753e+06
# Dual_func_value = -1.28753e+06
# Duality_gap = 0.137176
# Duality_gap / Duality_gap_init = 2.78775e-06
#
# Iterations number: 8000
# Primal_func_value = 1.28753e+06
# Dual_func_value = -1.28753e+06
# Duality_gap = 0.102449
# Duality_gap / Duality_gap_init = 2.08201e-06
#
# Iterations number: 10000
# Primal_func_value = 1.28753e+06
# Dual_func_value = -1.28753e+06
# Duality_gap = 0.0817142
# Duality_gap / Duality_gap_init = 1.66063e-06
#
# Result: success
# Total iters: 10000
# Primal_func_value = 1.28753e+06
# Dual_func_value = -1.28753e+06
# Duality_gap = 0.0817142
# Duality_gap / Duality_gap_init = 1.66063e-06
# Oracle elapsed time: 235 sec
# Elapsed time: 238 sec
# Time ratio = 3.289996798599943
# Flow excess = 0.9766724944905547

# %% [markdown]
# ## Universal Similar Triangles

# %%
epsilons = np.hstack([np.logspace(4, 3, 5)[:-1], np.logspace(3, -0.5, 8)])[::-1]
epsilons
# Out:
# array([3.16227766e-01, 1.00000000e+00, 3.16227766e+00, 1.00000000e+01,
#        3.16227766e+01, 1.00000000e+02, 3.16227766e+02, 1.00000000e+03,
#        1.77827941e+03, 3.16227766e+03, 5.62341325e+03, 1.00000000e+04])

# %%
assert(model.mu == 0.25)
max_iter = 10000
for index, eps_abs in enumerate(epsilons):
    print('eps_abs =', eps_abs)
    solver_kwargs = {'eps_abs': eps_abs,
                     'max_iter': max_iter, 'stop_crit': 'dual_gap',
                     'verbose' : True, 'verbose_step': 2000, 'save_history' : True}
    tic = time.time()
    result = model.find_equilibrium(solver_name = 'ustm', composite = True, solver_kwargs = solver_kwargs,
                                    t_start = t_free_flow)#t_start)
    toc = time.time()
    print('Elapsed time: {:.0f} sec'.format(toc - tic))
    print('Time ratio =', np.max(result['times'] / graph_data['graph_table']['free_flow_time']))
    print('Flow excess =', np.max(result['flows'] / graph_data['graph_table']['capacity']) - 1, end = '\n\n')

    result['eps_abs'] = eps_abs
    result['elapsed_time'] = toc - tic
    with open(beckmann_save + 'anaheim_result_' + 'ustm' + '_eps_abs_' + str(index) + '_beckmann.pickle', 'wb') as f:
        pickle.dump(result, f)
# Out:
# eps_abs = 0.31622776601683794
# Composite optimization...
# Oracles created...
# Universal similar triangles method...
# Given point is used as t_start...
# Primal_init = 1.29734e+06
# Dual_init = -1.24813e+06
# Duality_gap_init = 49206.9
#
# Iterations number: 2000
# Inner iterations number: 4009
# Primal_func_value = 1.28759e+06
# Dual_func_value = -1.28733e+06
# Duality_gap = 260.222
# Duality_gap / Duality_gap_init = 0.00528834
#
# Iterations number: 4000
# Inner iterations number: 8006
# Primal_func_value = 1.28755e+06
# Dual_func_value = -1.28748e+06
# Duality_gap = 66.1604
# Duality_gap / Duality_gap_init = 0.00134454
#
# Iterations number: 6000
# Inner iterations number: 12008
# Primal_func_value = 1.28753e+06
# Dual_func_value = -1.28751e+06
# Duality_gap = 20.2621
# Duality_gap / Duality_gap_init = 0.000411775
#
# Iterations number: 8000
# Inner iterations number: 16006
# Primal_func_value = 1.28753e+06
# Dual_func_value = -1.28752e+06
# Duality_gap = 10.9236
# Duality_gap / Duality_gap_init = 0.000221994
#
# Iterations number: 10000
# Inner iterations number: 20006
# Primal_func_value = 1.28753e+06
# Dual_func_value = -1.28752e+06
# Duality_gap = 5.8522
# Duality_gap / Duality_gap_init = 0.000118931
#
# Result: iterations number exceeded
# Total iters: 10000
# Primal_func_value = 1.28753e+06
# Dual_func_value = -1.28752e+06
# Duality_gap = 5.8522
# Duality_gap / Duality_gap_init = 0.000118931
# Oracle elapsed time: 602 sec
# Elapsed time: 610 sec
# Time ratio = 3.2762487860070615
# Flow excess = 0.9797807661844264
#
# eps_abs = 1.0
# Composite optimization...
# Oracles created...
# Universal similar triangles method...
# Given point is used as t_start...
# Primal_init = 1.29734e+06
# Dual_init = -1.24813e+06
# Duality_gap_init = 49206.9
#
# Iterations number: 2000
# Inner iterations number: 4005
# Primal_func_value = 1.28754e+06
# Dual_func_value = -1.2875e+06
# Duality_gap = 41.7844
# Duality_gap / Duality_gap_init = 0.000849157
#
# Iterations number: 4000
# Inner iterations number: 8004
# Primal_func_value = 1.28753e+06
# Dual_func_value = -1.28752e+06
# Duality_gap = 6.2585
# Duality_gap / Duality_gap_init = 0.000127188
#
# Iterations number: 6000
# Inner iterations number: 12000
# Primal_func_value = 1.28753e+06
# Dual_func_value = -1.28753e+06
# Duality_gap = 1.21804
# Duality_gap / Duality_gap_init = 2.47534e-05
#
# Result: success
# Total iters: 6277
# Primal_func_value = 1.28753e+06
# Dual_func_value = -1.28753e+06
# Duality_gap = 0.999932
# Duality_gap / Duality_gap_init = 2.0321e-05
# Oracle elapsed time: 373 sec
# Elapsed time: 378 sec
# Time ratio = 3.2856275585884434
# Flow excess = 0.9777265806300204
#
# eps_abs = 3.1622776601683795
# Composite optimization...
# Oracles created...
# Universal similar triangles method...
# Given point is used as t_start...
# Primal_init = 1.29734e+06
# Dual_init = -1.24813e+06
# Duality_gap_init = 49206.9
#
# Result: success
# Total iters: 1746
# Primal_func_value = 1.28753e+06
# Dual_func_value = -1.28752e+06
# Duality_gap = 3.1597
# Duality_gap / Duality_gap_init = 6.42126e-05
# Oracle elapsed time: 104 sec
# Elapsed time: 106 sec
# Time ratio = 3.2800876109009485
# Flow excess = 0.9791573654930255
#
# eps_abs = 10.0
# Composite optimization...
# Oracles created...
# Universal similar triangles method...
# Given point is used as t_start...
# Primal_init = 1.29734e+06
# Dual_init = -1.24813e+06
# Duality_gap_init = 49206.9
#
# Result: success
# Total iters: 531
# Primal_func_value = 1.28753e+06
# Dual_func_value = -1.28752e+06
# Duality_gap = 9.81449
# Duality_gap / Duality_gap_init = 0.000199454
# Oracle elapsed time: 32 sec
# Elapsed time: 32 sec
# Time ratio = 3.2690269199236934
# Flow excess = 0.9825048295498406
#
# eps_abs = 31.622776601683793
# Composite optimization...
# Oracles created...
# Universal similar triangles method...
# Given point is used as t_start...
# Primal_init = 1.29734e+06
# Dual_init = -1.24813e+06
# Duality_gap_init = 49206.9
#
# Result: success
# Total iters: 144
# Primal_func_value = 1.28754e+06
# Dual_func_value = -1.28751e+06
# Duality_gap = 31.0821
# Duality_gap / Duality_gap_init = 0.000631662
# Oracle elapsed time: 8 sec
# Elapsed time: 9 sec
# Time ratio = 3.2455974107176444
# Flow excess = 0.9927046281465679
#
# eps_abs = 100.0
# Composite optimization...
# Oracles created...
# Universal similar triangles method...
# Given point is used as t_start...
# Primal_init = 1.29734e+06
# Dual_init = -1.24813e+06
# Duality_gap_init = 49206.9
#
# Result: success
# Total iters: 53
# Primal_func_value = 1.28755e+06
# Dual_func_value = -1.28745e+06
# Duality_gap = 97.3594
# Duality_gap / Duality_gap_init = 0.00197857
# Oracle elapsed time: 3 sec
# Elapsed time: 3 sec
# Time ratio = 3.211551253426338
# Flow excess = 0.9999182691688673
#
# eps_abs = 316.22776601683796
# Composite optimization...
# Oracles created...
# Universal similar triangles method...
# Given point is used as t_start...
# Primal_init = 1.29734e+06
# Dual_init = -1.24813e+06
# Duality_gap_init = 49206.9
#
# Result: success
# Total iters: 20
# Primal_func_value = 1.2876e+06
# Dual_func_value = -1.2873e+06
# Duality_gap = 303.45
# Duality_gap / Duality_gap_init = 0.00616683
# Oracle elapsed time: 1 sec
# Elapsed time: 1 sec
# Time ratio = 3.145281701019879
# Flow excess = 1.0579488827661057
#
# eps_abs = 1000.0
# Composite optimization...
# Oracles created...
# Universal similar triangles method...
# Given point is used as t_start...
# Primal_init = 1.29734e+06
# Dual_init = -1.24813e+06
# Duality_gap_init = 49206.9
#
# Result: success
# Total iters: 12
# Primal_func_value = 1.28777e+06
# Dual_func_value = -1.28698e+06
# Duality_gap = 782.336
# Duality_gap / Duality_gap_init = 0.0158989
# Oracle elapsed time: 0 sec
# Elapsed time: 1 sec
# Time ratio = 3.0465232847601107
# Flow excess = 1.1585551098265303
#
# eps_abs = 1778.2794100389228
# Composite optimization...
# Oracles created...
# Universal similar triangles method...
# Given point is used as t_start...
# Primal_init = 1.29734e+06
# Dual_init = -1.24813e+06
# Duality_gap_init = 49206.9
#
# Result: success
# Total iters: 10
# Primal_func_value = 1.2881e+06
# Dual_func_value = -1.28652e+06
# Duality_gap = 1583.31
# Duality_gap / Duality_gap_init = 0.0321766
# Oracle elapsed time: 0 sec
# Elapsed time: 0 sec
# Time ratio = 2.84585746393987
# Flow excess = 1.3150514893328262
#
# eps_abs = 3162.2776601683795
# Composite optimization...
# Oracles created...
# Universal similar triangles method...
# Given point is used as t_start...
# Primal_init = 1.29734e+06
# Dual_init = -1.24813e+06
# Duality_gap_init = 49206.9
#
# Result: success
# Total iters: 10
# Primal_func_value = 1.2881e+06
# Dual_func_value = -1.28652e+06
# Duality_gap = 1583.31
# Duality_gap / Duality_gap_init = 0.0321766
# Oracle elapsed time: 0 sec
# Elapsed time: 0 sec
# Time ratio = 2.84585746393987
# Flow excess = 1.3150514893328262
#
# eps_abs = 5623.413251903491
# Composite optimization...
# Oracles created...
# Universal similar triangles method...
# Given point is used as t_start...
# Primal_init = 1.29734e+06
# Dual_init = -1.24813e+06
# Duality_gap_init = 49206.9
#
# Result: success
# Total iters: 8
# Primal_func_value = 1.28878e+06
# Dual_func_value = -1.28316e+06
# Duality_gap = 5618.73
# Duality_gap / Duality_gap_init = 0.114186
# Oracle elapsed time: 0 sec
# Elapsed time: 0 sec
# Time ratio = 1.872486740604319
# Flow excess = 1.350436955892519
#
# eps_abs = 10000.0
# Composite optimization...
# Oracles created...
# Universal similar triangles method...
# Given point is used as t_start...
# Primal_init = 1.29734e+06
# Dual_init = -1.24813e+06
# Duality_gap_init = 49206.9
#
# Result: success
# Total iters: 7
# Primal_func_value = 1.28926e+06
# Dual_func_value = -1.27995e+06
# Duality_gap = 9305.93
# Duality_gap / Duality_gap_init = 0.189119
# Oracle elapsed time: 0 sec
# Elapsed time: 0 sec
# Time ratio = 1.542092867192217
# Flow excess = 1.3632697362011528

# %%
'''
assert(model.mu == 0.25)
max_iter = 40000
for index, eps_abs in enumerate(epsilons):
    if index < len(epsilons) - 1:
        continue
    print('eps_abs =', eps_abs)
    solver_kwargs = {'eps_abs': eps_abs,
                     'max_iter': max_iter, 'stop_crit': 'dual_gap',
                     'verbose' : True, 'verbose_step': 4000, 'save_history' : True}
    tic = time.time()
    result = model.find_equilibrium(solver_name = 'ustm', composite = True, solver_kwargs = solver_kwargs,
                                    t_start = t_start)
    toc = time.time()
    print('Elapsed time: {:.0f} sec'.format(toc - tic))
    print('Time ratio =', np.max(result['times'] / graph_data['graph_table']['free_flow_time']))
    print('Flow excess =', np.max(result['flows'] / graph_data['graph_table']['capacity']) - 1, end = '\n\n')

    result['eps_abs'] = eps_abs
    result['elapsed_time'] = toc - tic
    with open(beckmann_save + 'anaheim_result_' + 'ustm' + '_eps_abs_' + str(index) + '_beckmann.pickle', 'wb') as f:
        pickle.dump(result, f)
'''
# Out:
# "\nassert(model.mu == 0.25)\nmax_iter = 40000\nfor index, eps_abs in enumerate(epsilons):\n    if index < len(epsilons) - 1:\n        continue\n    print('eps_abs =', eps_abs)\n    solver_kwargs = {'eps_abs': eps_abs,\n                     'max_iter': max_iter, 'stop_crit': 'dual_gap',\n                     'verbose' : True, 'verbose_step': 4000, 'save_history' : True}\n    tic = time.time()\n    result = model.find_equilibrium(solver_name = 'ustm', composite = True, solver_kwargs = solver_kwargs,\n                                    t_start = t_start)\n    toc = time.time()\n    print('Elapsed time: {:.0f} sec'.format(toc - tic))\n    print('Time ratio =', np.max(result['times'] / graph_data['graph_table']['free_flow_time']))\n    print('Flow excess =', np.max(result['flows'] / graph_data['graph_table']['capacity']) - 1, end = '\n\n')\n\n    result['eps_abs'] = eps_abs\n    result['elapsed_time'] = toc - tic\n    with open(beckmann_save + 'anaheim_result_' + 'ustm' + '_eps_abs_' + str(index) + '_beckmann.pickle', 'wb') as f:\n        pickle.dump(result, f)\n"

# %%
#index += 8
#epsilons = np.logspace(4, 3, 5)[:-1]
#epsilons

# %% [markdown]
# ## Universal Gradient Descent

# %%
epsilons = np.hstack([np.logspace(4, 3, 5)[:-1],np.logspace(3, 1, 7)])[::-1]
epsilons
# Out:
# array([   10.        ,    21.5443469 ,    46.41588834,   100.        ,
#          215.443469  ,   464.15888336,  1000.        ,  1778.27941004,
#         3162.27766017,  5623.4132519 , 10000.        ])

# %%
#weighted t added
assert(model.mu == 0.25)
max_iter = 10000
for index, eps_abs in enumerate(epsilons):
    print('eps_abs =', eps_abs)
    solver_kwargs = {'eps_abs': eps_abs,
                     'max_iter': max_iter, 'stop_crit': 'dual_gap',
                     'verbose' : True, 'verbose_step': 4000, 'save_history' : True}
    tic = time.time()
    result = model.find_equilibrium(solver_name = 'ugd', composite = True, solver_kwargs = solver_kwargs,
                                    t_start = t_free_flow)#t_start)
    toc = time.time()
    print('Elapsed time: {:.0f} sec'.format(toc - tic))
    print('Time ratio =', np.max(result['times'] / graph_data['graph_table']['free_flow_time']))
    print('Flow excess =', np.max(result['flows'] / graph_data['graph_table']['capacity']) - 1, end = '\n\n')
    
    result['eps_abs'] = eps_abs
    result['elapsed_time'] = toc - tic
    with open(beckmann_save + 'anaheim_result_' + 'ugd' + '_eps_abs_' + str(index) + '_beckmann.pickle', 'wb') as f:
        pickle.dump(result, f)
# Out:
# eps_abs = 10.0
# Composite optimization...
# Oracles created...
# Universal gradient descent method...
# Given point is used as t_start...
# Primal_init = 1.29734e+06
# Dual_init = -1.24813e+06
# Duality_gap_init = 49206.9
#
# Iterations number: 4000
# Inner iterations number: 8001
# Primal_func_value = 1.28782e+06
# Dual_func_value = -1.28663e+06
# Duality_gap = 1192.43
# Duality_gap / Duality_gap_init = 0.024233
#
# Iterations number: 8000
# Inner iterations number: 16001
# Primal_func_value = 1.28768e+06
# Dual_func_value = -1.28714e+06
# Duality_gap = 540.126
# Duality_gap / Duality_gap_init = 0.0109767
#
# Result: iterations number exceeded
# Total iters: 10000
# Primal_func_value = 1.28765e+06
# Dual_func_value = -1.28725e+06
# Duality_gap = 400.203
# Duality_gap / Duality_gap_init = 0.00813307
# Oracle elapsed time: 674 sec
# Elapsed time: 682 sec
# Time ratio = 2.830906470839499
# Flow excess = 1.1055327981372036
#
# eps_abs = 21.544346900318846
# Composite optimization...
# Oracles created...
# Universal gradient descent method...
# Given point is used as t_start...
# Primal_init = 1.29734e+06
# Dual_init = -1.24813e+06
# Duality_gap_init = 49206.9
#
# Iterations number: 4000
# Inner iterations number: 8002
# Primal_func_value = 1.28766e+06
# Dual_func_value = -1.2872e+06
# Duality_gap = 462.221
# Duality_gap / Duality_gap_init = 0.00939342
#
# Iterations number: 8000
# Inner iterations number: 15999
# Primal_func_value = 1.28759e+06
# Dual_func_value = -1.28741e+06
# Duality_gap = 181.954
# Duality_gap / Duality_gap_init = 0.00369774
#
# Result: iterations number exceeded
# Total iters: 10000
# Primal_func_value = 1.28758e+06
# Dual_func_value = -1.28744e+06
# Duality_gap = 133.751
# Duality_gap / Duality_gap_init = 0.00271813
# Oracle elapsed time: 676 sec
# Elapsed time: 683 sec
# Time ratio = 3.0546568665668343
# Flow excess = 1.0431850063979926
#
# eps_abs = 46.4158883361278
# Composite optimization...
# Oracles created...
# Universal gradient descent method...
# Given point is used as t_start...
# Primal_init = 1.29734e+06
# Dual_init = -1.24813e+06
# Duality_gap_init = 49206.9
#
# Iterations number: 4000
# Inner iterations number: 7999
# Primal_func_value = 1.28758e+06
# Dual_func_value = -1.28742e+06
# Duality_gap = 161.113
# Duality_gap / Duality_gap_init = 0.0032742
#
# Iterations number: 8000
# Inner iterations number: 15999
# Primal_func_value = 1.28755e+06
# Dual_func_value = -1.28749e+06
# Duality_gap = 63.4714
# Duality_gap / Duality_gap_init = 0.00128989
#
# Result: iterations number exceeded
# Total iters: 10000
# Primal_func_value = 1.28755e+06
# Dual_func_value = -1.2875e+06
# Duality_gap = 48.0302
# Duality_gap / Duality_gap_init = 0.000976087
# Oracle elapsed time: 677 sec
# Elapsed time: 685 sec
# Time ratio = 3.178627642487237
# Flow excess = 1.008655210299096
#
# eps_abs = 100.0
# Composite optimization...
# Oracles created...
# Universal gradient descent method...
# Given point is used as t_start...
# Primal_init = 1.29734e+06
# Dual_init = -1.24813e+06
# Duality_gap_init = 49206.9
#
# Result: success
# Total iters: 2560
# Primal_func_value = 1.28756e+06
# Dual_func_value = -1.28746e+06
# Duality_gap = 99.9833
# Duality_gap / Duality_gap_init = 0.0020319
# Oracle elapsed time: 172 sec
# Elapsed time: 174 sec
# Time ratio = 3.1062244318138528
# Flow excess = 1.0295359397697612
#
# eps_abs = 215.44346900318845
# Composite optimization...
# Oracles created...
# Universal gradient descent method...
# Given point is used as t_start...
# Primal_init = 1.29734e+06
# Dual_init = -1.24813e+06
# Duality_gap_init = 49206.9
#
# Result: success
# Total iters: 659
# Primal_func_value = 1.2876e+06
# Dual_func_value = -1.28738e+06
# Duality_gap = 215.342
# Duality_gap / Duality_gap_init = 0.00437625
# Oracle elapsed time: 45 sec
# Elapsed time: 45 sec
# Time ratio = 2.991751196363095
# Flow excess = 1.0631183298525646
#
# eps_abs = 464.15888336127773
# Composite optimization...
# Oracles created...
# Universal gradient descent method...
# Given point is used as t_start...
# Primal_init = 1.29734e+06
# Dual_init = -1.24813e+06
# Duality_gap_init = 49206.9
#
# Result: success
# Total iters: 198
# Primal_func_value = 1.28766e+06
# Dual_func_value = -1.2872e+06
# Duality_gap = 462.149
# Duality_gap / Duality_gap_init = 0.00939196
# Oracle elapsed time: 13 sec
# Elapsed time: 13 sec
# Time ratio = 2.8157430826283454
# Flow excess = 1.112210101888067
#
# eps_abs = 1000.0
# Composite optimization...
# Oracles created...
# Universal gradient descent method...
# Given point is used as t_start...
# Primal_init = 1.29734e+06
# Dual_init = -1.24813e+06
# Duality_gap_init = 49206.9
#
# Result: success
# Total iters: 54
# Primal_func_value = 1.28779e+06
# Dual_func_value = -1.28679e+06
# Duality_gap = 998.53
# Duality_gap / Duality_gap_init = 0.0202925
# Oracle elapsed time: 4 sec
# Elapsed time: 4 sec
# Time ratio = 2.586858971786378
# Flow excess = 1.177120300751882
#
# eps_abs = 1778.2794100389228
# Composite optimization...
# Oracles created...
# Universal gradient descent method...
# Given point is used as t_start...
# Primal_init = 1.29734e+06
# Dual_init = -1.24813e+06
# Duality_gap_init = 49206.9
#
# Result: success
# Total iters: 23
# Primal_func_value = 1.28795e+06
# Dual_func_value = -1.28621e+06
# Duality_gap = 1734.81
# Duality_gap / Duality_gap_init = 0.0352555
# Oracle elapsed time: 1 sec
# Elapsed time: 2 sec
# Time ratio = 2.3519177668397266
# Flow excess = 1.234213588967373
#
# eps_abs = 3162.2776601683795
# Composite optimization...
# Oracles created...
# Universal gradient descent method...
# Given point is used as t_start...
# Primal_init = 1.29734e+06
# Dual_init = -1.24813e+06
# Duality_gap_init = 49206.9
#
# Result: success
# Total iters: 14
# Primal_func_value = 1.28826e+06
# Dual_func_value = -1.28523e+06
# Duality_gap = 3031.77
# Duality_gap / Duality_gap_init = 0.0616128
# Oracle elapsed time: 1 sec
# Elapsed time: 1 sec
# Time ratio = 2.1104239820659685
# Flow excess = 1.2942141082960759
#
# eps_abs = 5623.413251903491
# Composite optimization...
# Oracles created...
# Universal gradient descent method...
# Given point is used as t_start...
# Primal_init = 1.29734e+06
# Dual_init = -1.24813e+06
# Duality_gap_init = 49206.9
#
# Result: success
# Total iters: 9
# Primal_func_value = 1.28861e+06
# Dual_func_value = -1.28441e+06
# Duality_gap = 4199.06
# Duality_gap / Duality_gap_init = 0.0853349
# Oracle elapsed time: 0 sec
# Elapsed time: 0 sec
# Time ratio = 2.03459514944231
# Flow excess = 1.3475101108936727
#
# eps_abs = 10000.0
# Composite optimization...
# Oracles created...
# Universal gradient descent method...
# Given point is used as t_start...
# Primal_init = 1.29734e+06
# Dual_init = -1.24813e+06
# Duality_gap_init = 49206.9
#
# Result: success
# Total iters: 8
# Primal_func_value = 1.28889e+06
# Dual_func_value = -1.28207e+06
# Duality_gap = 6825
# Duality_gap / Duality_gap_init = 0.1387
# Oracle elapsed time: 0 sec
# Elapsed time: 0 sec
# Time ratio = 1.6366481145949712
# Flow excess = 1.3586191721132899

# %% [markdown]
# ## Weighted Dual Averages

# %% [markdown]
# ### Composite optimization

# %%
assert(model.mu == 0.25)
max_iter = 10000
solver_kwargs = {'max_iter' : max_iter, 'stop_crit': 'max_iter',
                 'verbose': True, 'verbose_step': 4000, 'save_history': True}
tic = time.time()
result = model.find_equilibrium(solver_name = 'wda', composite = True, solver_kwargs = solver_kwargs,
                                t_start = t_free_flow)#t_start)
toc = time.time()
print('Elapsed time: {:.0f} sec'.format(toc - tic))
print('Time ratio =', np.max(result['times'] / graph_data['graph_table']['free_flow_time']))
print('Flow excess =', np.max(result['flows'] / graph_data['graph_table']['capacity']) - 1, end = '\n\n')

result['elapsed_time'] = toc - tic
with open(beckmann_save + 'anaheim_result_' + 'wda' + '_max_iter_' + str(max_iter) + '_beckmann.pickle', 'wb') as f:
    pickle.dump(result, f)
# Out:
# Composite optimization...
# Oracles created...
# Weighted dual averages method...
# Given point is used as t_start...
# Primal_init = 1.29734e+06
# Dual_init = -1.24813e+06
# Duality_gap_init = 49206.9
#
# Iterations number: 4000
# Primal_func_value = 1.28753e+06
# Dual_func_value = -1.28751e+06
# Duality_gap = 18.9342
# Duality_gap / Duality_gap_init = 0.000384789
#
# Iterations number: 8000
# Primal_func_value = 1.28753e+06
# Dual_func_value = -1.28752e+06
# Duality_gap = 9.91036
# Duality_gap / Duality_gap_init = 0.000201402
#
# Result: success
# Total iters: 10000
# Primal_func_value = 1.28753e+06
# Dual_func_value = -1.28752e+06
# Duality_gap = 8.029
# Duality_gap / Duality_gap_init = 0.000163168
# Oracle elapsed time: 298 sec
# Elapsed time: 302 sec
# Time ratio = 3.2391962958637164
# Flow excess = 0.9895868778813626

# %% [markdown]
# ## Plots

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import pickle
import numpy as np

# %%
beckmann_save = 'perturbation_results_seed/'
results = {}

for method in ['ustm', 'ugd']:
    results[method] = {}
    results[method]['iters'] = []
    results[method]['inner_iters'] = []
    results[method]['epsilon'] = []
    results[method]['dual_gap_init'] = []
    i = 0
    while True:
        try:
            with open(beckmann_save + 'anaheim_result_' + method + '_eps_abs_'
                      + str(i) + '_beckmann.pickle', 'rb') as f:
                result = pickle.load(f)
                results[method]['epsilon'].append(result['eps_abs'])
                results[method]['iters'].append(result['iter_num'])
                results[method]['inner_iters'].append(result['history'].get('inner_iters')[-1])
                results[method]['dual_gap_init'].append(result['history'].get('dual_gap')[0])
        except FileNotFoundError:
            break
        i += 1

        
for method in ['wda']:
    results[method] = {}
    with open(beckmann_save + 'anaheim_result_' + method + '_max_iter_10000_beckmann.pickle', 'rb') as f:
        result = pickle.load(f)
        results[method]['epsilon'] = result['history'].get('dual_gap')
        results[method]['iters'] = result['history'].get('iter')
        results[method]['dual_gap_init'] = result['history'].get('dual_gap')[0]
        
        
method = 'fwm'
with open(beckmann_save + 'anaheim_result_fwm_t_weighted_max_iter_10000_beckmann.pickle', 'rb') as f:
    results[method] = {}
    result = pickle.load(f)
    results[method]['epsilon'] = result['history'].get('dual_gap')
    results[method]['iters'] = result['history'].get('iter')
    results[method]['dual_gap_init'] = result['history'].get('dual_gap')[0]

# %%
beckmann_save = 'perturbation_results_free_flow_seed/'
results_ff = {}

for method in ['ustm', 'ugd']:
    results_ff[method] = {}
    results_ff[method]['iters'] = []
    results_ff[method]['inner_iters'] = []
    results_ff[method]['epsilon'] = []
    results_ff[method]['dual_gap_init'] = []
    i = 0
    while True:
        try:
            with open(beckmann_save + 'anaheim_result_' + method + '_eps_abs_'
                      + str(i) + '_beckmann.pickle', 'rb') as f:
                result = pickle.load(f)
                results_ff[method]['epsilon'].append(result['eps_abs'])
                results_ff[method]['iters'].append(result['iter_num'])
                results_ff[method]['inner_iters'].append(result['history'].get('inner_iters')[-1])
                results_ff[method]['dual_gap_init'].append(result['history'].get('dual_gap')[0])
        except FileNotFoundError:
            break
        i += 1

        
for method in ['wda']:
    results_ff[method] = {}
    with open(beckmann_save + 'anaheim_result_' + method + '_max_iter_10000_beckmann.pickle', 'rb') as f:
        result = pickle.load(f)
        results_ff[method]['epsilon'] = result['history'].get('dual_gap')
        results_ff[method]['iters'] = result['history'].get('iter')
        results_ff[method]['dual_gap_init'] = result['history'].get('dual_gap')[0]
        
        
method = 'fwm'
with open(beckmann_save + 'anaheim_result_fwm_t_weighted_max_iter_10000_beckmann.pickle', 'rb') as f:
    results_ff[method] = {}
    result = pickle.load(f)
    results_ff[method]['epsilon'] = result['history'].get('dual_gap')
    results_ff[method]['iters'] = result['history'].get('iter')
    results_ff[method]['dual_gap_init'] = result['history'].get('dual_gap')[0]

# %%
plt.figure(figsize=(10,6))
plt.title('Convergence for Beckmann model', fontsize=20)
eps_upper = 1e4
for method, data in results.items():
    x = 1. / np.array(data['epsilon'])
    y = np.array(data['iters'])
    ind = np.nonzero(1 / x <= eps_upper)
    plt.plot(x[ind], y[ind], label = method)
    
for (method, data), c in zip(results_ff.items(), ['steelblue', 'orange', 'green', 'red']):
    x = 1. / np.array(data['epsilon'])
    y = np.array(data['iters'])
    ind = np.nonzero(1 / x <= eps_upper)
    plt.plot(x[ind], y[ind], '--', c=c)
plt.legend(title = 'method')
plt.xscale('log')
plt.yscale('log')
plt.xlabel(r'1 / $\varepsilon$')
plt.ylabel('iterations')
plt.show()
